# %%
from sklearn.datasets import load_digits
import matplotlib.pyplot as plt


digits = load_digits()


print("Dataset Shape:", digits.data.shape)
print("Image Shape:", digits.images.shape)
print("Target Labels:", digits.target_names)


plt.figure(figsize=(4, 4))
plt.imshow(digits.images[5], cmap='gray')
plt.title(f"Label: {digits.target[0]}")
plt.axis('off')
plt.show()

# %%
from sklearn.datasets import load_digits
import matplotlib.pyplot as plt

digits = load_digits()

fig, axes = plt.subplots(5, 2, figsize=(10, 5))

for i, ax in enumerate(axes.flat):
    ax.imshow(digits.images[i], cmap='gray')
    ax.set_title(f"Digit: {digits.target[i]}")k7
    ax.axis('off') 

plt.tight_layout()
plt.show()

# %% [markdown]
# Q.write a python program to import iris datasets from scikitlearn and converted into dataframe and display the shape of the datasets?
#
# Q. write a python program to print complete description of the iris dataset display the shape of the datasets?
#
# Q. write a program the number of samples availables in iris datasets and digit datasets?

# %%
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
 
df = pd.DataFrame(iris.data, columns=iris.feature_names)

df["target"] = iris.target

print("Iris Dataset:")
print(df.head())

print("\nShape of the dataset:", df.shape)

# %%
from sklearn.datasets import load_iris

iris = load_iris()

print(iris.DESCR)

# %%
from sklearn.datasets import load_iris, load_digits

iris = load_iris()
digits = load_digits()

print("Number of samples in Iris dataset:", iris.data.shape[0])
print("Number of samples in Digits dataset:", digits.data.shape[0])

# %%
import json
student = {
    "Name": "Arup",
    "Department": "CSE",
    "Semester":5,
    "Subject":["AI&ML","Python", "Data Structure"]
}
with open("student.json","w")as file:
    json.dump(student,file,indent=4)
    print("JSON file created successfully.")
